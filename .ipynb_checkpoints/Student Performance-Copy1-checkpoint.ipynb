# %% [markdown]
# # **Project Title:** Predicting Student Performance

# %% [markdown]
# #### **Problem Statement**
#
# Students’ academic performance is shaped by many factors; how much they study, their past results, how well they sleep, and even whether they engage in extracurricular activities. Yet, it’s often unclear which of these factors matter most. This project aims to build a predictive model that uses such information to estimate a student’s performance index. The goal is to uncover the key drivers of success and provide insights that can help students, teachers, and parents take practical steps to improve learning outcomes.

# %% [markdown]
# #### **Objective**
#
# Predict Students' academic performance based on various factors

# %% [markdown]
# #### **Dataset Description**
#
# The dataset used in this project contains 10,000 records of student-related attributes that influence academic performance. It is a structured dataset with both numerical and categorical variables.
#
# - Number of Rows (Observations): 10,000
#
#
# - Number of Columns (Features): 6
#
#
# Features (Independent Variables / Predictors):
#
# 1. Hours Studied (int): Average number of study hours per day.
#
#
# 2. Previous Scores (int): Average performance in past academic assessments.
#
#
# 3. Extracurricular Activities (binary / categorical): Indicates student participation in extracurricular activities (e.g., 0 = No, 1 = Yes).
#
#
# 4. Sleep Hours (int): Average number of hours of sleep per day.
#
#
# 5. Sample Question Papers Practiced (int): Number of past exam/sample papers practiced by the student.
#
#
# Target Variable (Dependent Variable):
#
# - Performance Index (float): A numerical score ranging from 10 to 100, representing the student’s overall academic performance index.

# %% [markdown]
# ### **Import Required Libraries**

# %%
# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### **Loading dataset**

# %%
# Read the CSV file
Sp_df = pd.read_csv("Student_Performance.csv")

# %% [markdown]
# #### **Explore dataset**

# %%
# Display first few rows
Sp_df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
# Display last few rows
Sp_df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
# Display dataset information
Sp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
Sp_df.shape
# Out:
# (10000, 6)

# %%
Sp_df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
# List all columns
Sp_df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
# Quick stats
Sp_df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
# Check for missing values
Sp_df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
# Check for duplicate
Sp_df.duplicated().sum()
# Out:
# np.int64(127)

# %%
Sp_df.duplicated().value_counts()
# Out:
# False    9873
# True      127
# Name: count, dtype: int64

# %% [markdown]
# #### **Make all the necessary cleaning**

# %%
Sp_df.drop_duplicates()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [9873 rows x 6 columns]

# %%
Sp_df = Sp_df.drop_duplicates()

# %%
Sp_df.shape
# Out:
# (9873, 6)

# %% [markdown]
# **Observation:**
#
# It has 10,000 rows and 6 columns
#
# There are no missing values
#
# There are 127 duplicate rows in the dataset that were deleted
#
# The columns has their right datatypes

# %% [markdown]
# #### **Visualization of dataset**

# %%
# Visualize Distributions (Histograms)

# Plot distribution of each numeric feature
Sp_df.hist(figsize=(12, 8), bins=20, edgecolor='black')
plt.suptitle('Distribution of Numeric Features', fontsize=16)
plt.tight_layout(pad=2.0)  # Adjust padding to prevent overlap
plt.savefig('Feature Distributions.png', dpi = 300)
plt.show()

# %% [markdown]
# Correlation Matrix & Heatmap (Check Multicollinearity)

# %%
# Convert Yes/No to numeric
Sp_df['Extracurricular Activities'] = Sp_df['Extracurricular Activities'].map({'Yes': 1, 'No': 0})

# %%
# Correlation matrix
corr = Sp_df.corr()
corr
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                          1.000000        -0.010676
# Previous Scores                       -0.010676         1.000000
# Extracurricular Activities             0.004899         0.009534
# Sleep Hours                            0.002131         0.007975
# Sample Question Papers Practiced       0.015740         0.008719
# Performance Index                      0.375332         0.915135
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.004899     0.002131
# Previous Scores                                     0.009534     0.007975
# Extracurricular Activities                          1.000000    -0.024008
# Sleep Hours                                        -0.024008     1.000000
# Sample Question Papers Practiced                    0.013839     0.004907
# Performance Index                                   0.026075     0.050352
#
#                                   Sample Question Papers Practiced  \
# Hours Studied                                             0.015740
# Previous Scores                                           0.008719
# Extracurricular Activities                                0.013839
# Sleep Hours                                               0.004907
# Sample Question Papers Practiced                          1.000000
# Performance Index                                         0.043436
#
#                                   Performance Index
# Hours Studied                              0.375332
# Previous Scores                            0.915135
# Extracurricular Activities                 0.026075
# Sleep Hours                                0.050352
# Sample Question Papers Practiced           0.043436
# Performance Index                          1.000000

# %%
# Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.tight_layout()  # Adjusts layout so labels are visible
plt.savefig('correlation_matrix.png', bbox_inches='tight', dpi= 300)
plt.show()

# %%
# Correlation Explanation & Performance Index Relationship
correlation_values = Sp_df.corr()["Performance Index"].sort_values(ascending=False)

# %%
print(correlation_values)
# Out:
# Performance Index                   1.000000
# Previous Scores                     0.915135
# Hours Studied                       0.375332
# Sleep Hours                         0.050352
# Sample Question Papers Practiced    0.043436
# Extracurricular Activities          0.026075
# Name: Performance Index, dtype: float64

# %% [markdown]
#  Boxplot – Performance by Extracurricular Activities

# %%
# Boxplot
plt.figure(figsize=(6,4))  # Control plot size

# Map 0 -'No', 1 -'Yes' for display only
sns.boxplot(
    x=Sp_df['Extracurricular Activities'].map({0: 'No', 1: 'Yes'}),
    y=Sp_df['Performance Index']
)

plt.title("Performance Index by Extracurricular Activities")
plt.xlabel("Extracurricular Activities")
plt.ylabel("Performance Index")
plt.savefig('Performance by Extracurricular Activities.png', dpi = 300)
plt.show()

# %%
# Boxplot to detect outliers

plt.figure(figsize=(10, 6))
sns.boxplot(data=Sp_df, palette="Set2")
plt.xticks(rotation=45)
plt.title("Boxplot of Features to Detect Outliers")
plt.savefig("Boxplot of Features to Detect Outliers.png", bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# #### **Load ML libraries**

# %%
# Modeling

# splitting
from sklearn.model_selection import train_test_split

# linear models
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# tree-based models
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# kernel / margin-based
from sklearn.svm import SVR

# gradient boosting (XGBoost)
from xgboost import XGBRegressor

# preprocessing
from sklearn.preprocessing import StandardScaler

# Evaluation
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score

# %% [markdown]
# #### **Prepare Data for Modeling**

# %%
# Define features (X) and target (y)
X = Sp_df.drop(columns=["Performance Index"])
y = Sp_df["Performance Index"]

# %% [markdown]
# #### **Split the dataset**

# %%
# 80% train, 20% test
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# #### **Standardize the dataset**

# %%
# Feature Scaling

# Fit scaler only on training set
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)  # fit + transform on train
X_test_scaled  = scaler.transform(X_test)       # only transform on test

# %%
# Convert back to DataFrame for readability 
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X.columns, index=X_train.index)
X_test_scaled  = pd.DataFrame(X_test_scaled, columns=X.columns, index=X_test.index)

# %%
X_train_scaled.head()
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 8495       0.003721         0.096536                   -0.993941    -1.497153
# 9012      -1.156282        -0.712663                    1.006096     0.268403
# 4092      -1.542949        -1.175062                   -0.993941    -1.497153
# 811       -0.769614        -0.654863                    1.006096    -0.320116
# 6789      -0.769614         0.616735                   -0.993941     0.856921
#
#       Sample Question Papers Practiced
# 8495                         -0.208907
# 9012                         -1.257157
# 4092                         -1.606574
# 811                          -1.257157
# 6789                          1.188761

# %%
X_test_scaled.head()
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 6057      -0.382947        -0.308064                    1.006096    -0.908634
# 106        0.777056         1.194734                    1.006096    -1.497153
# 9154       0.390388         0.212135                    1.006096    -0.320116
# 4680      -0.769614        -1.521862                   -0.993941    -0.320116
# 2149       1.550391         0.385535                   -0.993941     1.445440
#
#       Sample Question Papers Practiced
# 6057                          0.140510
# 106                          -1.257157
# 9154                         -1.257157
# 4680                          1.188761
# 2149                          1.188761

# %% [markdown]
# #### **Train the model**

# %% [markdown]
# **Linear Regression**

# %%
# Initialize and train the model
lr_model = LinearRegression()
lr_model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
# Predict on test data
y_pred_lr = lr_model.predict(X_test_scaled)

# Evaluate model performance
mse_lr = mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
r2_lr = r2_score(y_test, y_pred_lr)

print(f"Linear Regression RMSE: {rmse_lr:.2f}, R²: {r2_lr:.2f}")
# Out:
# Linear Regression RMSE: 2.08, R²: 0.99

# %% [markdown]
# **Ridge Regression**

# %%
# Initialize and train the model
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train_scaled, y_train)
# Out:
# Ridge()

# %%
# Predict on test data
y_pred_ridge = ridge_model.predict(X_test_scaled)

# Evaluate model performance
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
rmse_ridge = np.sqrt(mse_ridge)
r2_ridge = r2_score(y_test, y_pred_ridge)

print(f"Ridge Regression RMSE: {rmse_ridge:.2f}, R²: {r2_ridge:.2f}")
# Out:
# Ridge Regression RMSE: 2.08, R²: 0.99

# %% [markdown]
# **Lasso Regression**

# %%
# Initialize and train the model
lasso_model = Lasso(alpha=0.01)
lasso_model.fit(X_train_scaled, y_train)
# Out:
# Lasso(alpha=0.01)

# %%
# Predict on test data
y_pred_lasso = lasso_model.predict(X_test_scaled)

# Evaluate model performance
mse_lasso = mean_squared_error(y_test, y_pred_lasso)
rmse_lasso = np.sqrt(mse_lasso)
r2_lasso = r2_score(y_test, y_pred_lasso)

print(f"Lasso Regression RMSE: {rmse_lasso:.2f}, R²: {r2_lasso:.2f}")
# Out:
# Lasso Regression RMSE: 2.08, R²: 0.99

# %% [markdown]
# **Decision Tree Regressor**

# %%
# Initialize and train the Decision Tree model
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Predict on test data
y_pred_dt = dt_model.predict(X_test_scaled)

# Evaluate Decision Tree model performance
mse_dt = mean_squared_error(y_test, y_pred_dt)
rmse_dt = root_mean_squared_error(y_test, y_pred_dt)
r2_dt = r2_score(y_test, y_pred_dt)

print("RMSE for Decision Tree: ", rmse_dt )
print("R² Score for Desision Tree: ", r2_dt) 
print(f"Decision Tree Regressor RMSE: {rmse_dt:.2f}, R²: {r2_dt:.2f}")
# Out:
# RMSE for Decision Tree:  3.044046089720584
# R² Score for Desision Tree:  0.9751018413090885
# Decision Tree Regressor RMSE: 3.04, R²: 0.98

# %% [markdown]
# **Random Forest Regressor**

# %%
# Initialize and train the model
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict on test data
y_pred_rf = rf_model.predict(X_test_scaled)

# Evaluate model performance
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print(f"Random Forest RMSE: {rmse_rf:.2f}, R²: {r2_rf:.2f}")
# Out:
# Random Forest RMSE: 2.37, R²: 0.98

# %% [markdown]
# **Support Vector Regressor (SVR)**

# %%
# Initialize and train the SVR model
svr_model = SVR(kernel='rbf')
svr_model.fit(X_train_scaled, y_train)
# Out:
# SVR()

# %%
# Predict on test data
y_pred_svr = svr_model.predict(X_test_scaled)

# Evaluate SVR model performance
mse_svr = mean_squared_error(y_test, y_pred_svr)
rmse_svr = root_mean_squared_error(y_test, y_pred_svr)
r2_svr = r2_score(y_test, y_pred_svr)
 
print("RMSE for SVR: ", rmse_svr )
print("R² Score for SVR: ", r2_svr)
print(f"Support Vector Regressor (SVR) RMSE: {rmse_svr:.2f}, R²: {r2_svr:.2f}")
# Out:
# RMSE for SVR:  2.3638023583252457
# R² Score for SVR:  0.9849863216883314
# Support Vector Regressor (SVR) RMSE: 2.36, R²: 0.98

# %% [markdown]
# **Gradient Boosting (XGBoost)**

# %%
# Initialize and train the model
xgb_model = XGBRegressor(objective='reg:squarederror', random_state=42)
xgb_model.fit(X_train_scaled, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# Predict on test data
y_pred_xgb = xgb_model.predict(X_test_scaled)

# Evaluate model performance
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)

print(f"XGBoost RMSE: {rmse_xgb:.2f}, R²: {r2_xgb:.2f}")
# Out:
# XGBoost RMSE: 2.26, R²: 0.99

# %% [markdown]
# **Compare Model Performances**

# %%
results = pd.DataFrame({
    'Model': ['Linear Regression', 'Ridge Regression', 'Lasso Regression', 'Decision Tree', 'Random Forest', 'Support Vector Machine', 'XGBoost'],
    'RMSE': [rmse_lr, rmse_ridge, rmse_lasso, rmse_dt, rmse_rf, rmse_svr, rmse_xgb],
    'R²': [r2_lr, r2_ridge, r2_lasso, r2_dt, r2_rf, r2_svr, r2_xgb]
})

results.sort_values(by='RMSE', inplace=True)
results
# Out:
#                     Model      RMSE        R²
# 0       Linear Regression  2.075066  0.988430
# 1        Ridge Regression  2.075077  0.988430
# 2        Lasso Regression  2.076465  0.988415
# 6                 XGBoost  2.263701  0.986231
# 5  Support Vector Machine  2.363802  0.984986
# 4           Random Forest  2.373178  0.984867
# 3           Decision Tree  3.044046  0.975102

# %% [markdown]
# **Model Performance Summary**
#
# Linear, Ridge, and Lasso Regression achieved the best results (RMSE ≈ 2.07, R² ≈ 0.988), showing high accuracy and reliability. XGBoost, Random Forest, and SVM also performed well but offered no clear advantage. The Decision Tree had the weakest performance.
#
# **Chosen Model:** I will proceed with Linear Regression as the best balance of accuracy and interpretability.

# %% [markdown]
# **Feature Importance Analysis (LR)**

# %%
# Get feature importance from LR model
feature_importance_lr = pd.Series(lr_model.coef_, index=X_scaled.columns).sort_values(ascending=False)

# %%
# Plot feature importance
plt.figure(figsize=(8, 5))
sns.barplot(x=feature_importance_lr.values, y=feature_importance_lr.index, palette="viridis", hue = feature_importance_lr.index, legend = False)
plt.title("Feature Importance in LR Model")
plt.xlabel("Coefficient Value (Impact on Performance Index)")
plt.ylabel("Feature")
plt.savefig("Coefficient Value (Impact on Performance Index).png", dpi = 300)
plt.show()

# %%
# Display feature importance values
feature_importance_lr
# Out:
# Previous Scores                     17.619931
# Hours Studied                        7.373316
# Sleep Hours                          0.802138
# Sample Question Papers Practiced     0.540053
# Extracurricular Activities           0.286906
# dtype: float64

# %% [markdown]
# **Feature Importance Analysis (Linear Regression)**
#
# The analysis shows that Previous Scores (17.62) is by far the most influential factor in predicting student performance, meaning past academic achievement strongly determines future outcomes.
#
# Hours Studied (7.37) also plays a significant role, highlighting the importance of consistent study habits.
#
# Sleep Hours (0.80) and Sample Question Papers Practiced (0.54) have a smaller but still positive contribution.
#
# Extracurricular Activities (0.29) has the least impact, suggesting that while valuable for overall development, it contributes minimally to academic performance prediction in this dataset.
#
# **Conclusion:** Prior academic performance and study time are the strongest predictors of student performance, while lifestyle and extracurricular factors play relatively minor roles.

# %% [markdown]
# #### **Make Predictions**

# %%
# Example: new/unseen student data 
# One new student record 
new_student = pd.DataFrame({ 
    'Hours Studied': [7], 
    'Previous Scores': [75], 
    'Extracurricular Activities': [1], # 1 = Yes, 0 = No 
    'Sleep Hours': [6], 
    'Sample Question Papers Practiced': [3] 
}) 
# Predict Performance Index 
predicted_score = lr_model.predict(new_student) 
print("Predicted Performance Index:", predicted_score[0])
# Out:
# Predicted Performance Index: 1434.9238909971389

# %%
# Example: new/unseen student data

# One new student record
new_student = pd.DataFrame({
    'Hours Studied': [7],
    'Previous Scores': [75],
    'Extracurricular Activities': [1],  # 1 = Yes, 0 = No
    'Sleep Hours': [6],
    'Sample Question Papers Practiced': [3]
})

# Apply the SAME scaler used during training
new_student_scaled = scaler.transform(new_student)

# Predict Performance Index
predicted_score = lr_model.predict(new_student_scaled)

print("Predicted Performance Index:", predicted_score[0])
# Out:
# Predicted Performance Index: 1436.8926830917312

# %%
import pandas as pd 
# New unseen student records 
new_students = pd.DataFrame({ 
    'Hours Studied': [2, 5, 8, 3, 6], 
    'Previous Scores': [40, 60, 85, 55, 72], 
    'Extracurricular Activities': [0, 1, 1, 0, 1], # 1 = Yes, 0 = No 
    'Sleep Hours': [4, 7, 6, 5, 8], 
    'Sample Question Papers Practiced': [1, 2, 5, 1, 4] 
}) 
# Predict Performance Index for new records 
predicted_scores = lr_model.predict(new_students)

# Combine inputs and predictions for readability 
results = new_students.copy() 
results['Predicted Performance Index'] = predicted_scores 
results
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              2               40                           0            4
# 1              5               60                           1            7
# 2              8               85                           1            6
# 3              3               55                           0            5
# 4              6               72                           1            8
#
#    Sample Question Papers Practiced  Predicted Performance Index
# 0                                 1                   778.388444
# 1                                 2                  1156.140382
# 2                                 5                  1619.576621
# 3                                 1                  1050.862860
# 4                                 4                  1376.835112

# %%
# New unseen student records
new_students = pd.DataFrame({
    'Hours Studied': [2, 5, 8, 3, 6],
    'Previous Scores': [40, 60, 85, 55, 72],
    'Extracurricular Activities': [0, 1, 1, 0, 1],  # 1 = Yes, 0 = No
    'Sleep Hours': [4, 7, 6, 5, 8],
    'Sample Question Papers Practiced': [1, 2, 5, 1, 4]
})

# Apply the SAME scaler used during training
new_students_scaled = scaler.transform(new_students)

# Predict Performance Index
predicted_scores = lr_model.predict(new_students_scaled)

# Combine inputs and predictions for readability
results = new_students.copy()
results['Predicted Performance Index'] = predicted_scores

results
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              2               40                           0            4
# 1              5               60                           1            7
# 2              8               85                           1            6
# 3              3               55                           0            5
# 4              6               72                           1            8
#
#    Sample Question Papers Practiced  Predicted Performance Index
# 0                                 1                   779.474337
# 1                                 2                  1157.730376
# 2                                 5                  1621.796129
# 3                                 1                  1052.317246
# 4                                 4                  1378.723261

# %%
import pandas as pd
import numpy as np

# One new student record
new_student = pd.DataFrame({
    'Hours Studied': [7],
    'Previous Scores': [75],
    'Extracurricular Activities': [1],  # 1 = Yes, 0 = No
    'Sleep Hours': [6],
    'Sample Question Papers Practiced': [3]
})

# Predict Performance Index
predicted_score = lr_model.predict(new_student)

# Clip prediction to range [10, 100]
predicted_score = np.clip(predicted_score, 10, 100)

print("Predicted Performance Index:", predicted_score[0])
# Out:
# Predicted Performance Index: 100.0

# %%
import pandas as pd
import numpy as np

# New unseen student records
new_students = pd.DataFrame({
    'Hours Studied': [2, 5, 8, 3, 6],
    'Previous Scores': [40, 60, 85, 55, 72],
    'Extracurricular Activities': [0, 1, 1, 0, 1],  # 1 = Yes, 0 = No
    'Sleep Hours': [4, 7, 6, 5, 8],
    'Sample Question Papers Practiced': [1, 2, 5, 1, 4]
})

# Predict Performance Index for new records
predicted_scores = lr_model.predict(new_students)

# Clip predictions to range [10, 100]
predicted_scores = np.clip(predicted_scores, 10, 100)

# Combine inputs and predictions for readability
results = new_students.copy()
results['Predicted Performance Index'] = predicted_scores

results
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              2               40                           0            4
# 1              5               60                           1            7
# 2              8               85                           1            6
# 3              3               55                           0            5
# 4              6               72                           1            8
#
#    Sample Question Papers Practiced  Predicted Performance Index
# 0                                 1                        100.0
# 1                                 2                        100.0
# 2                                 5                        100.0
# 3                                 1                        100.0
# 4                                 4                        100.0

# %%
import pandas as pd

# New, unseen student records with more varied input values
new_students = pd.DataFrame({
    "Hours Studied": [1, 4, 7, 10, 12],
    "Previous Scores": [20, 50, 70, 85, 95],
    "Extracurricular Activities": [0, 1, 0, 1, 0],
    "Sleep Hours": [3, 6, 7, 8, 5],
    "Sample Question Papers Practiced": [0, 2, 4, 6, 8]
})

# Make predictions
predictions = lr_model.predict(new_students)

# Clip predictions to the valid range (10–100)
predictions = predictions.clip(10, 100)

# Combine inputs with predictions
new_students["Predicted Performance Index"] = predictions
new_students
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              1               20                           0            3
# 1              4               50                           1            6
# 2              7               70                           0            7
# 3             10               85                           1            8
# 4             12               95                           0            5
#
#    Sample Question Papers Practiced  Predicted Performance Index
# 0                                 0                        100.0
# 1                                 2                        100.0
# 2                                 4                        100.0
# 3                                 6                        100.0
# 4                                 8                        100.0

# %%
import pandas as pd

# New, more realistic unseen student records
new_students = pd.DataFrame({
    'Hours Studied': [2, 4, 7, 9, 5],
    'Previous Scores': [35, 50, 78, 90, 65],
    'Extracurricular Activities': [0, 1, 1, 0, 1],
    'Sleep Hours': [5, 7, 6, 8, 4],
    'Sample Question Papers Practiced': [1, 2, 4, 5, 3]
})

# Predict
predictions = lr_model.predict(new_students)

# Clip predictions to valid range 10–100
predictions = predictions.clip(10, 100)

# Add predictions to dataframe
new_students['Predicted Performance Index'] = predictions
new_students
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              2               35                           0            5
# 1              4               50                           1            7
# 2              7               78                           1            6
# 3              9               90                           0            8
# 4              5               65                           1            4
#
#    Sample Question Papers Practiced  Predicted Performance Index
# 0                                 1                        100.0
# 1                                 2                        100.0
# 2                                 4                        100.0
# 3                                 5                        100.0
# 4                                 3                        100.0

# %%
import pandas as pd

# Step 1: Define new student records with varied inputs
new_students = {
    'Hours Studied': [1, 4, 7, 10, 15],
    'Previous Scores': [20, 50, 75, 90, 95],
    'Extracurricular Activities': [0, 1, 0, 1, 1],
    'Sleep Hours': [3, 6, 5, 7, 8],
    'Sample Question Papers Practiced': [0, 2, 5, 7, 10]
}

# Step 2: Create dataframe
new_students_df = pd.DataFrame(new_students)

# Step 3: Make predictions using your trained model
new_predictions = lr_model.predict(new_students_df)

# Step 4: Clip predictions to the valid range [10, 100]
new_predictions_clipped = new_predictions.clip(10, 100)

# Step 5: Combine inputs with predictions
results_df = new_students_df.copy()
results_df['Predicted Performance Index'] = new_predictions_clipped

# Step 6: Show results
print(results_df)
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              1               20                           0            3
# 1              4               50                           1            6
# 2              7               75                           0            5
# 3             10               90                           1            7
# 4             15               95                           1            8
#
#    Sample Question Papers Practiced  Predicted Performance Index
# 0                                 0                        100.0
# 1                                 2                        100.0
# 2                                 5                        100.0
# 3                                 7                        100.0
# 4                                10                        100.0

# %%
# Make raw predictions (without clipping)
new_predictions_raw = lr_model.predict(new_students_df)

# Show raw predictions
new_students_df["Raw Predicted Performance Index"] = new_predictions_raw
print(new_students_df)
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              1               20                           0            3
# 1              4               50                           1            6
# 2              7               75                           0            5
# 3             10               90                           1            7
# 4             15               95                           1            8
#
#    Sample Question Papers Practiced  Raw Predicted Performance Index
# 0                                 0                       417.274321
# 1                                 2                       971.765620
# 2                                 5                      1434.914953
# 3                                 7                      1724.305152
# 4                                10                      1851.693683

# %%
import pandas as pd

new_students_df = pd.DataFrame({
    "Hours Studied": [1, 10, 20, 5, 15],
    "Previous Scores": [20, 95, 70, 50, 88],
    "Extracurricular Activities": [0, 1, 1, 0, 1],
    "Sleep Hours": [3, 8, 6, 5, 7],
    "Sample Question Papers Practiced": [0, 10, 5, 2, 8]
})

# Predict without clipping
new_predictions_raw = lr_model.predict(new_students_df)

# Clip to 10–100
new_predictions_clipped = new_predictions_raw.clip(10, 100)

new_students_df["Raw Predicted Performance Index"] = new_predictions_raw
new_students_df["Final Predicted Performance Index"] = new_predictions_clipped

print(new_students_df)
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              1               20                           0            3
# 1             10               95                           1            8
# 2             20               70                           1            6
# 3              5               50                           0            5
# 4             15               88                           1            7
#
#    Sample Question Papers Practiced  Raw Predicted Performance Index  \
# 0                                 0                       417.274321
# 1                                10                      1814.827103
# 2                                 5                      1443.757451
# 3                                 2                       978.049891
# 4                                 8                      1726.471923
#
#    Final Predicted Performance Index
# 0                              100.0
# 1                              100.0
# 2                              100.0
# 3                              100.0
# 4                              100.0

# %%
# new unseen student records
new_students = pd.DataFrame({
    "Hours Studied": [2, 5, 8, 3, 6],
    "Previous Scores": [40, 60, 85, 55, 72],
    "Extracurricular Activities": [0, 1, 1, 0, 1],
    "Sleep Hours": [4, 7, 6, 5, 8],
    "Sample Question Papers Practiced": [1, 2, 5, 1, 4]
})

# scale new data with the SAME scaler
new_students_scaled = scaler.transform(new_students)

# predict
predictions = lr_model.predict(new_students_scaled)

# clip to 10–100
predictions = np.clip(predictions, 10, 100)

new_students["Predicted Performance Index"] = predictions
new_students
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              2               40                           0            4
# 1              5               60                           1            7
# 2              8               85                           1            6
# 3              3               55                           0            5
# 4              6               72                           1            8
#
#    Sample Question Papers Practiced  Predicted Performance Index
# 0                                 1                        100.0
# 1                                 2                        100.0
# 2                                 5                        100.0
# 3                                 1                        100.0
# 4                                 4                        100.0

# %%
# new unseen student records
new_students = pd.DataFrame({
    "Hours Studied": [2, 5, 8, 3, 6],
    "Previous Scores": [40, 60, 85, 55, 72],
    "Extracurricular Activities": [0, 1, 1, 0, 1],
    "Sleep Hours": [4, 7, 6, 5, 8],
    "Sample Question Papers Practiced": [1, 2, 5, 1, 4]
})

# scale new data with the SAME scaler
new_students_scaled = scaler.transform(new_students)

# predict
predictions = rf_model.predict(new_students_scaled)

# clip to 10–100
predictions = np.clip(predictions, 10, 100)

new_students["Predicted Performance Index"] = predictions
new_students
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              2               40                           0            4
# 1              5               60                           1            7
# 2              8               85                           1            6
# 3              3               55                           0            5
# 4              6               72                           1            8
#
#    Sample Question Papers Practiced  Predicted Performance Index
# 0                                 1                    95.920833
# 1                                 2                    96.733333
# 2                                 5                    96.733333
# 3                                 1                    95.920833
# 4                                 4                    96.733333

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Example new student records (raw values)
new_students = {
    'Hours Studied': [2, 5, 8, 3, 6],
    'Previous Scores': [40, 60, 85, 55, 72],
    'Extracurricular Activities': [0, 1, 1, 0, 1],
    'Sleep Hours': [4, 7, 6, 5, 8],
    'Sample Question Papers Practiced': [1, 2, 5, 1, 4]
}

new_students_df = pd.DataFrame(new_students)

# Apply the SAME scaler used during training
new_students_scaled = scaler.transform(new_students_df)

# Predict (scaled input → model → prediction)
predictions = lr_model.predict(new_students_scaled)

# Clip to valid range
predictions_clipped = predictions.clip(10, 100)

# Attach predictions to dataframe
new_students_df["Predicted Performance Index"] = predictions_clipped

new_students_df
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              2               40                           0            4
# 1              5               60                           1            7
# 2              8               85                           1            6
# 3              3               55                           0            5
# 4              6               72                           1            8
#
#    Sample Question Papers Practiced  Predicted Performance Index
# 0                                 1                        100.0
# 1                                 2                        100.0
# 2                                 5                        100.0
# 3                                 1                        100.0
# 4                                 4                        100.0

# %% [markdown]
# #### **Conclusion**

# %% [markdown]
# I developed a Multiple Linear Regression model to predict student performance. The results showed that previous scores and hours studied were the most influential factors, while sleep, extracurricular activities, and practice questions had smaller effects. This highlights the importance of academic history and consistent study time in shaping student outcomes.

# %% [markdown]
# #### **Deployment on Streamlit**
